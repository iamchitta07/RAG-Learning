# %% [markdown]
# ### 🧠 What is Query Planning and Decomposition?
# Query Planning and Decomposition is a technique where a complex user query is broken down into simpler sub-questions or tasks, allowing a system (like a RAG agent) to:
#
# - Understand the question more deeply
# - Retrieve more precise and complete information
# - Execute step-by-step reasoning
#
# It's like reverse-engineering a question into manageable steps before answering.
#
# 🧠 What's New in This Version?
# - ✅ Add a Query Planner Node
# - ✅ Break complex user queries into sub-questions
# - ✅ Retrieve docs per sub-question
# - ✅ Combine all retrieved contexts
# - ✅ Generate a final consolidated answer

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
from typing import List
from pydantic import BaseModel
from langchain_ollama import OllamaEmbeddings
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_classic.vectorstores import FAISS
from langchain_community.document_loaders import WebBaseLoader
from langgraph.graph import StateGraph, END
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model= "gemma4:e4b")

# %%
# ----------------------------
# 1. Load and Embed Documents
# ----------------------------
urls = [
    "https://lilianweng.github.io/posts/2023-06-23-agent/",
    "https://lilianweng.github.io/posts/2024-04-12-diffusion-video/"
]
docs = []
for url in urls:
    docs.extend(WebBaseLoader(url).load())

splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
chunks = splitter.split_documents(docs)

embedding = OllamaEmbeddings(model="qwen3-embedding:8b")
vectorstore = FAISS.from_documents(chunks, embedding)
retriever = vectorstore.as_retriever()

# %%
# ----------------------------
# 2. State Schema
# ----------------------------
class RAGState(BaseModel):
    question: str
    sub_questions: List[str] = []
    retrieved_docs: List[Document] = []
    answer: str = ""

# %%
# ----------------------------
# 3. Nodes
# ----------------------------

## a. Query Planner: splits input question
def plan_query(state: RAGState) -> RAGState:
    prompt = f"""
Break the following complex question into 2-3 sub-questions:

Question: {state.question}

Sub-questions:
"""
    result = llm.invoke(prompt)
    sub_questions = [line.strip("- ").strip() for line in result.content.strip().split("\n") if line.strip()]
    return RAGState(question= state.question, sub_questions= sub_questions)

## b. Retrieve documents for each sub-question
def retrieve_for_each(state: RAGState) -> RAGState:
    all_docs = []
    for sub in state.sub_questions:
        docs = retriever.invoke(sub)
        all_docs.extend(docs)
    return RAGState(question= state.question, sub_questions= state.sub_questions, retrieved_docs= all_docs)

## c. Generate final answer
def generate_final_answer(state: RAGState) -> RAGState:
    context = "\n\n".join([doc.page_content for doc in state.retrieved_docs])
    prompt = f"""
Use the context below to answer the question.

Context:
{context}

Question: {state.question}
"""
    
    answer = llm.invoke(prompt).content
    return RAGState(question= state.question, sub_questions= state.sub_questions, retrieved_docs= state.retrieved_docs, answer= answer)

# %%
# ----------------------------
# 4. Build LangGraph
# ----------------------------
builder = StateGraph(RAGState)

builder.add_node("planner", plan_query)
builder.add_node("retriever", retrieve_for_each)
builder.add_node("responder", generate_final_answer)

builder.set_entry_point("planner")
builder.add_edge("planner", "retriever")
builder.add_edge("retriever", "responder")
builder.add_edge("responder", END)

graph = builder.compile()
graph

# %%
# ----------------------------
# 5. Run the pipeline
# ----------------------------
if __name__ == "__main__":
    user_query = "Explain how agent loops work and what are the challenges in diffusion video generation?"
    initial_state = RAGState(question= user_query)
    final_state = graph.invoke(initial_state)
    print(final_state)

    print("\n🔍 Sub-questions:")
    for q in final_state['sub_questions']:
        print("-", q)

    print("\n✅ Final Answer:\n", final_state['answer'])
# Out:
# {'question': 'Explain how agent loops work and what are the challenges in diffusion video generation?', 'sub_questions': ['This complex question requires the separation of two entirely distinct, highly technical domains: AI/Control Systems (Agent Loops) and Generative AI/Computer Vision (Diffusion Video).', 'The most effective way to break it down is to dedicate one sub-question to each major topic.', '### Sub-questions:', '**1. Defining Agent Loops:**', '> What is the operational mechanism of "agent loops," and how do they function in facilitating iterative decision-making or autonomous task completion?', '**2. Addressing Video Generation:**', '> What are the primary technical and methodological challenges currently facing the development and deployment of state-of-the-art diffusion models for video generation?', '***', '#### **Why this works:**', '*   **Clarity:** It completely separates the two topics, preventing the answer from becoming a confused comparison.', '*   **Scope:** Each sub-question is broad enough to require a detailed, academic explanation, but narrow enough to be focused (e.g., "operational mechanism" vs. "challenges").', '*   **Manageability:** The individual sub-questions can be researched or explained independently.'], 'retrieved_docs': [Document(id='aca29d1e-a54a-458a-a967-5c8aa8aa5713', metadata={'source': 'https://lilianweng.github.io/posts/2024-04-12-diffusion-video/', 'title': "Diffusion Models for Video Generation | Lil'Log", 'description': 'Diffusion models have demonstrated strong results on image synthesis in past years. Now the research community has started working on a harder task—using it for video generation. The task itself is a superset of the image case, since an image is a video of 1 frame, and it is much more challenging because:\n\nIt has extra requirements on temporal consistency across frames in time, which naturally demands more world knowledge to be encoded into the model.\nIn comparison to text or images, it is more difficult to collect large amounts of high-quality, high-dimensional video data, let along text-video pairs.\n\n\n\n🥑 Required Pre-read: Please make sure you have read the previous blog on “What are Diffusion Models?” for image generation before continue here.\n', 'language': 'en-us'}, page_content='The overview of ControlVideo. (Image source: Zhang et al. 2023)\n\nCitation#\nCited as:\n\nWeng, Lilian. (Apr 2024). Diffusion Models Video Generation. Lil’Log. https://lilianweng.github.io/posts/2024-04-12-diffusion-video/.'), Document(id='2152ecfa-e4be-4a24-9230-518af840f24e', metadata={'source': 'https://lilianweng.github.io/posts/2024-04-12-diffusion-video/', 'title': "Diffusion Models for Video Generation | Lil'Log", 'description': 'Diffusion models have demonstrated strong results on image synthesis in past years. Now the research community has started working on a harder task—using it for video generation. The task itself is a superset of the image case, since an image is a video of 1 frame, and it is much more challenging because:\n\nIt has extra requirements on temporal consistency across frames in time, which naturally demands more world knowledge to be encoded into the model.\nIn comparison to text or images, it is more difficult to collect large amounts of high-quality, high-dimensional video data, let along text-video pairs.\n\n\n\n🥑 Required Pre-read: Please make sure you have read the previous blog on “What are Diffusion Models?” for image generation before continue here.\n', 'language': 'en-us'}, page_content='[3] Bar-Tal et al. 2024 “Lumiere: A Space-Time Diffusion Model for Video Generation.”\n[4] Brooks et al. “Video generation models as world simulators.” OpenAI Blog, 2024.\n[5] Zhang et al. 2023 “ControlVideo: Training-free Controllable Text-to-Video Generation.”\n[6] Khachatryan et al. 2023 “Text2Video-Zero: Text-to-image diffusion models are zero-shot video generators.”\n[7] Ho, et al. 2022 “Imagen Video: High Definition Video Generation with Diffusio ...
#
# 🔍 Sub-questions:
# - This complex question requires the separation of two entirely distinct, highly technical domains: AI/Control Systems (Agent Loops) and Generative AI/Computer Vision (Diffusion Video).
# - The most effective way to break it down is to dedicate one sub-question to each major topic.
# - ### Sub-questions:
# - **1. Defining Agent Loops:**
# - > What is the operational mechanism of "agent loops," and how do they function in facilitating iterative decision-making or autonomous task completion?
# - **2. Addressing Video Generation:**
# - > What are the primary technical and methodological challenges currently facing the development and deployment of state-of-the-art diffusion models for video generation?
# - ***
# - #### **Why this works:**
# - *   **Clarity:** It completely separates the two topics, preventing the answer from becoming a confused comparison.
# - *   **Scope:** Each sub-question is broad enough to require a detailed, academic explanation, but narrow enough to be focused (e.g., "operational mechanism" vs. "challenges").
# - *   **Manageability:** The individual sub-questions can be researched or explained independently.
#
# ✅ Final Answer:
#  Based on the context provided, here is an explanation of how agent loops work and the challenges involved in diffusion video generation.
#
# ***
#
# ### 🤖 How Agent Loops Work
#
# Agent systems, particularly those powered by Large Language Models (LLMs), function through a structured combination of several key components that enable them to handle complex tasks iteratively—a concept analogous to an agent loop.
#
# The design of these generative agents combines:
#
# 1.  **LLM as the Core Controller (The Brain):** The LLM functions as the primary intelligence that drives the agent.
# 2.  **Memory:** The agent maintains a record of past observations and experiences.
# 3.  **Planning:** When faced with a complicated task, the agent must plan ahead. This involves **Task Decomposition**, where the agent breaks down a large, complex goal into smaller, manageable subgoals.
# 4.  **Reflection and Refinement:** The agent incorporates a mechanism for self-correction. It performs self-criticism and self-reflection over its past actions and learned mistakes, which allows it to refine its approach and improve the quality of future steps.
#
# In essence, the system enables the agent to behave conditioned on past experience by planning its steps, executing them, observing the results, and then critically reflecting on those results to guide future actions.
#
# ### 🎬 Challenges in Diffusion Video Generation
#
# The transition from image synthesis to video generation is described as a significant leap in complexity. The context highlights several challenges:
#
# 1.  **Increased Complexity (Superset Task):** Video generation is a superset of the image case. Since an image is merely a video of one frame, generating a continuous video is much more difficult than generating a static image.
# 2.  **Decomposition Challenge:** Models like Gen-1, which target editing videos based on text, must decompose the consideration of a video's structure and its content ($p(\mathbf{x} \mid s, c)$) for conditioning. The context notes that achieving a clear decomposition between these two aspects is particularly challenging.
# 3.  **Modeling from Scratch:** Designing and training diffusion video models without relying on pre-trained image generators (i.e., "from scratch") is a major area of ongoing research, necessitating novel approaches such as adapting image models or fine-tuning extensively on video data.
